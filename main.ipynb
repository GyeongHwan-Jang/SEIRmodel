# %%
import SEIRmodel

# %%
SEIR = SEIRmodel.SEIRmodel(initN = 100, beta = 0.5, sigma = 0.1, gamma = 0.33, initI = 10)
SEIR.run(100, verbose = True)
SEIR.plot(title = "SEIRmodel", plot_style = "line",figsize= (15,13))
# Out:
# t = 99.90
# 	 S   = 33.342247131347676
# 	 E   = 0.8316858058021869
# 	 I   = 0.28802228279440034
# 	 R   = 65.53804478005571
