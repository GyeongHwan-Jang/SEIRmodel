# %%
import SEIRmodel

# %%
SEIR = SEIRmodel.SEIRmodel(100, 0.66, 0.5, 0.3, initI=10)
SEIR.run(100)
SEIR.plot("SEIR model")
# Out:
# t = 99.90

# %%
SEIR = SEIRmodel.SEIRmodel(100, 0.66, 0.5, 0.3, initI=10)
SEIR.run(100)
SEIR.plot("SEIR model", plot_style = "stacked")
# Out:
# t = 99.90
