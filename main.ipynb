# %%
import SEIRmodel

# %%
SEIR = SEIRmodel.SEIRmodel(initN = 100, beta = 0.1, sigma = 0.1, gamma = 0.1, initI = 10)
SEIR.run(100)
SEIR.figure_basic(title = "SEIRmodel", figsize= (15,13))
# Out:
# t = 99.90
# /root/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# (<Figure size 1080x936 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f430cc4a9d0>)
