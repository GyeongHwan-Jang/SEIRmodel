# %% [markdown]
# # Simulating SI by differential equation

# %%
# import model package
import Compartment_Model
import numpy as np

# import plot package
import matplotlib.pyplot as plt

# %%
# simulate SImodel with line plot
SI = Compartment_Model.SImodel(100, 0.5, initI=1)
SI.run(100)
SI.plot("SI model", S_plot = "line", I_plot = "line")

# %%
# simulate SImodel with stacked plot
SI = Compartment_Model.SImodel(100, 0.5, initI=1)
SI.run(100)
SI.plot("SI model", S_plot = "stacked", I_plot = "stacked")

# %%
# simulate SImodel with various beta 
SI1 = Compartment_Model.SImodel(100, 0.3, initI=10)
SI2 = Compartment_Model.SImodel(100, 0.5, initI=10)
SI3 = Compartment_Model.SImodel(100, 0.8, initI=10)

SI1.run(100)
SI2.run(100)
SI3.run(100)

fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SI1.tseries, SI1.numI / SI1.N, label = "beta = 0.3")
ax.plot(SI2.tseries, SI2.numI / SI2.N, label = "beta = 0.5")
ax.plot(SI3.tseries, SI3.numI / SI3.N, label = "beta = 0.8")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xlim(0, (max(SI1.tseries)))
ax.set_ylim(0, max(SI3.numI/SI3.N)+0.05)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SI model", size=40)

plt.show()

# %%
# simulate SImodel with various beta 
SI1 = Compartment_Model.SImodel(100, 0.3, initI=10)
SI2 = Compartment_Model.SImodel(100, 0.5, initI=10)
SI3 = Compartment_Model.SImodel(100, 0.8, initI=10)

SI1.run(100)
SI2.run(100)
SI3.run(100)

fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SI1.tseries, SI1.numI / SI1.N, label = "beta = 0.3")
ax.plot(SI2.tseries, SI2.numI / SI2.N, label = "beta = 0.5")
ax.plot(SI3.tseries, SI3.numI / SI3.N, label = "beta = 0.8")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
# ax.set_xlim(0, (max(SI1.tseries)))
# ax.set_ylim(0, max(SI3.numI/SI3.N)+0.05)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)
ax.set_xscale("log")
ax.set_yscale("log")

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SI model", size=40)

plt.show()

# %%
# simulate SImodel with various initial I 
SI1 = Compartment_Model.SImodel(100, 0.3, initI=10)
SI2 = Compartment_Model.SImodel(100, 0.3, initI=30)
SI3 = Compartment_Model.SImodel(100, 0.3, initI=50)

SI1.run(100)
SI2.run(100)
SI3.run(100)

fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SI1.tseries, SI1.numI / SI1.N, label = "$I_0$ = 10%")
ax.plot(SI2.tseries, SI2.numI / SI2.N, label = "$I_0$ = 30%")
ax.plot(SI3.tseries, SI3.numI / SI3.N, label = "$I_0$ = 50%")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xlim(0, (max(SI1.tseries)))
ax.set_ylim(0, max(SI3.numI/SI3.N)+0.05)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SI model", size=40)

plt.show()

# %%
# simulate SImodel with various initial I 
SI1 = Compartment_Model.SImodel(100, 0.3, initI=10)
SI2 = Compartment_Model.SImodel(100, 0.3, initI=30)
SI3 = Compartment_Model.SImodel(100, 0.3, initI=50)

SI1.run(100)
SI2.run(100)
SI3.run(100)

fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SI1.tseries, SI1.numI / SI1.N, label = "$I_0$ = 10%")
ax.plot(SI2.tseries, SI2.numI / SI2.N, label = "$I_0$ = 30%")
ax.plot(SI3.tseries, SI3.numI / SI3.N, label = "$I_0$ = 50%")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
# ax.set_xlim(0, (max(SI1.tseries)))
# ax.set_ylim(0, max(SI3.numI/SI3.N)+0.05)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)
ax.set_xscale("log")
# ax.set_yscale("log")

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SI model", size=40)

plt.show()

# %% [markdown]
# # Simulating SIS by differential equation

# %%
# simulate SISmodel with line plot
SIS = Compartment_Model.SISmodel(100, 0.5, 0.3,initI=10)
SIS.run(100)
SIS.plot("SIS model", S_plot = "line", I_plot = "line")

# %%
# simulate SISmodel with stacked plot
SIS= Compartment_Model.SISmodel(100, 0.5, 0.3, initI=10)
SIS.run(100)
SIS.plot("SIS model", S_plot = "stacked", I_plot = "stacked")

# %%
# simulate SISmodel with various beta 
SIS1 = Compartment_Model.SISmodel(100, 0.1, 0.3, initI=10)
SIS2 = Compartment_Model.SISmodel(100, 0.3, 0.3, initI=10)
SIS3 = Compartment_Model.SISmodel(100, 0.5, 0.3, initI=10)
SIS4 = Compartment_Model.SISmodel(100, 0.7, 0.3, initI=10)
SIS5 = Compartment_Model.SISmodel(100, 0.9, 0.3, initI=10)

SIS1.run(100)
SIS2.run(100)
SIS3.run(100)
SIS4.run(100)
SIS5.run(100)


fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SIS1.tseries, SIS1.numI / SIS1.N, label = "beta = 0.1")
ax.plot(SIS2.tseries, SIS2.numI / SIS2.N, label = "beta = 0.3")
ax.plot(SIS3.tseries, SIS3.numI / SIS3.N, label = "beta = 0.5")
ax.plot(SIS4.tseries, SIS4.numI / SIS4.N, label = "beta = 0.7")
ax.plot(SIS5.tseries, SIS5.numI / SIS5.N, label = "beta = 0.9")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xlim(0, (max(SIS5.tseries)))
ax.set_ylim(0, max(SIS5.numI/SIS5.N)+0.05)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SIS model", size=40)

plt.show()

# %%
# simulate SISmodel with various beta 
SIS1 = Compartment_Model.SISmodel(100, 0.5, 0.1, initI=10)
SIS2 = Compartment_Model.SISmodel(100, 0.5, 0.3, initI=10)
SIS3 = Compartment_Model.SISmodel(100, 0.5, 0.5, initI=10)
SIS4 = Compartment_Model.SISmodel(100, 0.5, 0.7, initI=10)
SIS5 = Compartment_Model.SISmodel(100, 0.5, 0.9, initI=10)

SIS1.run(100)
SIS2.run(100)
SIS3.run(100)
SIS4.run(100)
SIS5.run(100)


fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SIS1.tseries, SIS1.numI / SIS1.N, label = "gamma = 0.1")
ax.plot(SIS2.tseries, SIS2.numI / SIS2.N, label = "gamma = 0.3")
ax.plot(SIS3.tseries, SIS3.numI / SIS3.N, label = "gamma = 0.5")
ax.plot(SIS4.tseries, SIS4.numI / SIS4.N, label = "gamma = 0.7")
ax.plot(SIS5.tseries, SIS5.numI / SIS5.N, label = "gamma = 0.9")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xlim(0, (max(SIS1.tseries)))
ax.set_ylim(0, max(SIS1.numI/SIS1.N)+0.05)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SIS model", size=40)

plt.show()

# %%
# simulate SISmodel with rate of beta and gamma

final_infected = []
for i in np.arange(0,2,0.01):
    SIS = Compartment_Model.SISmodel(100, 0.5*i, 0.5, initI=10)
    SIS.run(1000)
    final_infected.append(SIS.numI[-1]/SIS.N)

fig, ax = plt.subplots(figsize = (12,8))

ax.plot(np.arange(0,2,0.01), final_infected)

ax.set_xlabel('$ \\beta / \gamma $', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:,.2f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)
ax.set_xlim(0,2.01)
ax.set_ylim(0, max(final_infected)+0.05)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SIS model", size=40)

plt.show()

# %%
# simulate SISmodel with rate of beta and gamma

SIS = Compartment_Model.SISmodel(100, 0.5, 0.3, initI=10)
SIS.run(100)

fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SIS.tseries, (SIS.numS/SIS.N)*(SIS.beta/SIS.gamma))

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('$ R_e $', fontsize = 25)
ax.set_xlim(0, (max(SIS.tseries)))
ax.set_ylim(min((SIS.numS/SIS.N)*(SIS.beta/SIS.gamma))-0.1, max((SIS.numS/SIS.N)*(SIS.beta/SIS.gamma))+0.1)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:,.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.2f}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SIS model", size=40)

plt.show()

# %% [markdown]
# # Simulating SIR by differential equation

# %%
# simulate SIRmodel with line plot
SIR = Compartment_Model.SIRmodel(100, 0.5, 0.3, initI=10)
SIR.run(100)
SIR.plot("SIR model", S_plot = "line", I_plot = "line", R_plot = "line")

# %%
# simulate SIRmodel with stacked plot
SIR = Compartment_Model.SIRmodel(100, 0.5, 0.3, initI=10)
SIR.run(100)
SIR.plot("SIR model", S_plot = "stacked", I_plot = "stacked", R_plot = "stacked")

# %%
# simulate SIRmodel with various beta 
SIR1 = Compartment_Model.SIRmodel(100, 0.1, 0.3, initI=10)
SIR2 = Compartment_Model.SIRmodel(100, 0.3, 0.3, initI=10)
SIR3 = Compartment_Model.SIRmodel(100, 0.5, 0.3, initI=10)
SIR4 = Compartment_Model.SIRmodel(100, 0.7, 0.3, initI=10)
SIR5 = Compartment_Model.SIRmodel(100, 0.9, 0.3, initI=10)

SIR1.run(100)
SIR2.run(100)
SIR3.run(100)
SIR4.run(100)
SIR5.run(100)


fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SIR1.tseries, SIR1.numI / SIR1.N, label = "beta = 0.1")
ax.plot(SIR2.tseries, SIR2.numI / SIR2.N, label = "beta = 0.3")
ax.plot(SIR3.tseries, SIR3.numI / SIR3.N, label = "beta = 0.5")
ax.plot(SIR4.tseries, SIR4.numI / SIR4.N, label = "beta = 0.7")
ax.plot(SIR5.tseries, SIR5.numI / SIR5.N, label = "beta = 0.9")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xlim(0, (max(SIR5.tseries)))
ax.set_ylim(0, max(SIR5.numI/SIR5.N)+0.01)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SIR model", size=40)

plt.show()

# %%
# simulate SIRmodel with various gamma
SIR1 = Compartment_Model.SIRmodel(100, 0.5, 0.1, initI=10)
SIR2 = Compartment_Model.SIRmodel(100, 0.5, 0.3, initI=10)
SIR3 = Compartment_Model.SIRmodel(100, 0.5, 0.5, initI=10)
SIR4 = Compartment_Model.SIRmodel(100, 0.5, 0.7, initI=10)
SIR5 = Compartment_Model.SIRmodel(100, 0.5, 0.9, initI=10)

SIR1.run(100)
SIR2.run(100)
SIR3.run(100)
SIR4.run(100)
SIR5.run(100)


fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SIR1.tseries, SIR1.numI / SIR1.N, label = "gamma = 0.1")
ax.plot(SIR2.tseries, SIR2.numI / SIR2.N, label = "gamma = 0.3")
ax.plot(SIR3.tseries, SIR3.numI / SIR3.N, label = "gamma = 0.5")
ax.plot(SIR4.tseries, SIR4.numI / SIR4.N, label = "gamma = 0.7")
ax.plot(SIR5.tseries, SIR5.numI / SIR5.N, label = "gamma = 0.9")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xlim(0, (max(SIR1.tseries)))
ax.set_ylim(0, max(SIR1.numI/SIR1.N)+0.01)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SIR model", size=40)

plt.show()

# %%
# simulate SIRmodel with rate of beta and gamma

final_infected = []
for i in np.arange(0,2,0.01):
    SIR = Compartment_Model.SISmodel(100, 0.5*i, 0.5, initI=10)
    SIR.run(1000)
    final_infected.append(SIR.numI[-1]/SIR.N)

fig, ax = plt.subplots(figsize = (12,8))

ax.plot(np.arange(0,2,0.01), final_infected)

ax.set_xlabel('$ \\beta / \gamma $', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:,.2f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)
ax.set_xlim(0,2.01)
ax.set_ylim(0, max(final_infected)+0.05)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SIR model", size=40)

plt.show()

# %%
# simulate SIRmodel with rate of beta and gamma

SIR = Compartment_Model.SIRmodel(100, 0.5, 0.3, initI=10)
SIR.run(100)

fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SIR.tseries, (SIR.numS/SIR.N)*(SIR.beta/SIR.gamma))

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('$ R_e $', fontsize = 25)
ax.set_xlim(0, (max(SIR.tseries)))
ax.set_ylim(min((SIR.numS/SIS.N)*(SIR.beta/SIR.gamma))-0.1, max((SIR.numS/SIR.N)*(SIR.beta/SIR.gamma))+0.1)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:,.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.2f}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SIR model", size=40)

plt.show()

# %% [markdown]
# # Simulating SEIR by differential equation

# %%
import Compartment_Model
import matplotlib.pyplot as plt

# %%
SEIR = Compartment_Model.SEIRmodel(100, 0.5, 0.3, 0.3, initI=10)
SEIR.run(100)
SEIR.plot("SEIR model")

# %%
SEIR = Compartment_Model.SEIRmodel(100, 0.5, 0.3, 0.3, initI=10)
SEIR.run(100)
SEIR.plot("SEIR model", S_plot = "stacked", E_plot = "stacked", I_plot = "stacked", R_plot = "stacked")

# %%
# simulate SIRmodel with various beta
SEIR1 = Compartment_Model.SEIRmodel(100, 0.1, 0.3, 0.3, initI=10)
SEIR2 = Compartment_Model.SEIRmodel(100, 0.3, 0.3, 0.3, initI=10)
SEIR3 = Compartment_Model.SEIRmodel(100, 0.5, 0.3, 0.3, initI=10)
SEIR4 = Compartment_Model.SEIRmodel(100, 0.7, 0.3, 0.3, initI=10)
SEIR5 = Compartment_Model.SEIRmodel(100, 0.9, 0.3, 0.3, initI=10)

SEIR1.run(100)
SEIR2.run(100)
SEIR3.run(100)
SEIR4.run(100)
SEIR5.run(100)


fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SEIR1.tseries, SEIR1.numI / SEIR1.N, label = "beta = 0.1")
ax.plot(SEIR2.tseries, SEIR2.numI / SEIR2.N, label = "beta = 0.3")
ax.plot(SEIR3.tseries, SEIR3.numI / SEIR3.N, label = "beta = 0.5")
ax.plot(SEIR4.tseries, SEIR4.numI / SEIR4.N, label = "beta = 0.7")
ax.plot(SEIR5.tseries, SEIR5.numI / SEIR5.N, label = "beta = 0.9")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xlim(0, (max(SEIR5.tseries)))
ax.set_ylim(0, max(SEIR5.numI/SEIR5.N)+0.01)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SEIR model", size=40)

plt.show()

# %%
# simulate SIRmodel with various sigma
SEIR1 = Compartment_Model.SEIRmodel(100, 0.5, 0.1, 0.3, initI=10)
SEIR2 = Compartment_Model.SEIRmodel(100, 0.5, 0.3, 0.3, initI=10)
SEIR3 = Compartment_Model.SEIRmodel(100, 0.5, 0.5, 0.3, initI=10)
SEIR4 = Compartment_Model.SEIRmodel(100, 0.5, 0.7, 0.3, initI=10)
SEIR5 = Compartment_Model.SEIRmodel(100, 0.5, 0.9, 0.3, initI=10)

SEIR1.run(100)
SEIR2.run(100)
SEIR3.run(100)
SEIR4.run(100)
SEIR5.run(100)


fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SEIR1.tseries, SEIR1.numI / SEIR1.N, label = "sigma = 0.1")
ax.plot(SEIR2.tseries, SEIR2.numI / SEIR2.N, label = "sigma = 0.3")
ax.plot(SEIR3.tseries, SEIR3.numI / SEIR3.N, label = "sigma = 0.5")
ax.plot(SEIR4.tseries, SEIR4.numI / SEIR4.N, label = "sigma = 0.7")
ax.plot(SEIR5.tseries, SEIR5.numI / SEIR5.N, label = "sigma = 0.9")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xlim(0, (max(SEIR5.tseries)))
ax.set_ylim(0, max(SEIR5.numI/SEIR5.N)+0.01)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SEIR model", size=40)

plt.show()

# %%
# simulate SIRmodel with various sigma
SEIR1 = Compartment_Model.SEIRmodel(100, 0.5, 0.5, 0.1, initI=10)
SEIR2 = Compartment_Model.SEIRmodel(100, 0.5, 0.5, 0.3, initI=10)
SEIR3 = Compartment_Model.SEIRmodel(100, 0.5, 0.5, 0.5, initI=10)
SEIR4 = Compartment_Model.SEIRmodel(100, 0.5, 0.5, 0.7, initI=10)
SEIR5 = Compartment_Model.SEIRmodel(100, 0.5, 0.5, 0.9, initI=10)

SEIR1.run(100)
SEIR2.run(100)
SEIR3.run(100)
SEIR4.run(100)
SEIR5.run(100)


fig, ax = plt.subplots(figsize = (12,8))

ax.plot(SEIR1.tseries, SEIR1.numI / SEIR1.N, label = "gamma = 0.1")
ax.plot(SEIR2.tseries, SEIR2.numI / SEIR2.N, label = "gamma = 0.3")
ax.plot(SEIR3.tseries, SEIR3.numI / SEIR3.N, label = "gamma = 0.5")
ax.plot(SEIR4.tseries, SEIR4.numI / SEIR4.N, label = "gamma = 0.7")
ax.plot(SEIR5.tseries, SEIR5.numI / SEIR5.N, label = "gamma = 0.9")

ax.set_xlabel('simulation time', fontsize = 30)
ax.set_ylabel('percent of infected population', fontsize = 25)
ax.set_xlim(0, (max(SEIR1.tseries)))
ax.set_ylim(0, max(SEIR1.numI/SEIR1.N)+0.01)
ax.set_xticks(ax.get_xticks())
ax.set_yticks(ax.get_yticks())
ax.set_xticklabels(['{:.0f}'.format(x) for x in ax.get_xticks()],fontsize = 25)
ax.set_yticklabels(['{:,.0%}'.format(y) if y != 0 else "" for y in ax.get_yticks()],fontsize = 25)

legend_handles, legend_labels = ax.get_legend_handles_labels()
ax.legend(legend_handles[::-1], legend_labels[::-1], loc='upper right', facecolor='white', edgecolor='none', framealpha=0.9, prop={'size': 15})
ax.set_title("SEIR model", size=40)

plt.show()

# %% [markdown]
# # Simulating SEIR by agent-based model
